# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('housing.data', delim_whitespace=True, header=None)

# %%
col_name = ['CRIM', 'ZN' , 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
df.columns = col_name

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# # Linear Regression with Scikit-Learn

# %%
X = df['RM'].values.reshape(-1,1)

# %%
y = df['MEDV'].values

# %% [markdown]
# ## Entrenar una regresion linera utilizando Sklearn
# Importar el modelo LinearRegression de SkLearn

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Entrenar el model con X como feature, e y como la variable objetivo

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Mostrar el coeficente y el intercept del modelo entrenado

# %%
# Out:
# array([9.10210898])

# %%
# Out:
# -34.67062077643857

# %% [markdown]
# Plotear el dataset y la regresion utilizando seaborn.

# %%
plt.figure(figsize=(12,10));
sns.regplot(X, y);
plt.xlabel('average number of rooms per dwelling')
plt.ylabel("Median value of owner-occupied homes in $1000's")
plt.show();

# %%
sns.jointplot(x='MEDV', y='RM', data=df, kind='reg', height=10);
plt.show();
